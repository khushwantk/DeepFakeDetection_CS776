# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fashionmnist/t10k-labels-idx1-ubyte
# /kaggle/input/fashionmnist/t10k-images-idx3-ubyte
# /kaggle/input/fashionmnist/fashion-mnist_test.csv
# /kaggle/input/fashionmnist/fashion-mnist_train.csv
# /kaggle/input/fashionmnist/train-labels-idx1-ubyte
# /kaggle/input/fashionmnist/train-images-idx3-ubyte

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# %%
train_df = pd.read_csv('../input/fashionmnist/fashion-mnist_train.csv',sep=',')
test_df = pd.read_csv('../input/fashionmnist/fashion-mnist_test.csv', sep = ',')


train_data = np.array(train_df, dtype = 'float32')
test_data = np.array(test_df, dtype='float32')
X_train = train_data[:,1:]
y_train = np.array(train_data[:,0])
X_test= test_data[:,1:]
y_test=np.array(test_data[:,0])

print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (60000, 784) (60000,)
# (10000, 784) (10000,)

# %%
def preprocess_data(X_train, X_test, eps=1e-8):
    
    # Normalization 
    X_train = X_train/ 255.0
    X_test = X_test/ 255.0

    # Standardization
    # Compute mean and std from TRAINING DATA only
    mean = np.mean(X_train, axis=0)
    std = np.std(X_train, axis=0) + eps  # Avoid division by zero
    X_train_processed = (X_train - mean) / std
    X_test_processed = (X_test - mean) / std
    
    return X_train_processed, X_test_processed

X_train, X_test = preprocess_data(X_train, X_test)

print("Processed Training Data Shape:", X_train.shape)  # (60000, 784)
print("Processed Test Data Shape:", X_test.shape)       # (10000, 784)
# Out:
# Processed Training Data Shape: (60000, 784)
# Processed Test Data Shape: (10000, 784)

# %%
# Split before one-hot encoding
x_train, x_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

y_train = y_train.astype(int)
y_val = y_val.astype(int)
y_test = y_test.astype(int)

# One-hot encoding AFTER splitting
num_classes=10
y_train = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)
y_test = to_categorical(y_test, num_classes)

# Print dataset shapes
print("Training set shape:", x_train.shape, y_train.shape)
print("Validation set shape:", x_val.shape, y_val.shape)
print("Original Testing set shape:", X_test.shape, y_test.shape)
# Out:
# Training set shape: (48000, 784) (48000, 10)
# Validation set shape: (12000, 784) (12000, 10)
# Original Testing set shape: (10000, 784) (10000, 10)

# %%
num_images = 3
fig,axes = plt.subplots(1,num_images,figsize=(15,10))
for image,label,ax in zip(x_train[:num_images],y_train[:num_images],axes):
    ax.imshow(image.reshape(28,28),cmap='gray',vmin=0,vmax=1.0)
    ax.set_title(f"Label: {label}")

# %%
# Helper Functions

def relu(x):
    return np.maximum(0, x)

def relu_derivative(x):
    return (x > 0).astype(float)

def leaky_relu(x, alpha=0.01):
    return np.where(x > 0, x, alpha * x)

def leaky_relu_derivative(x, alpha=0.01):
    return np.where(x > 0, 1, alpha)

def tanh(x):
    return np.tanh(x)

def tanh_derivative(x):
    return 1 - np.tanh(x)**2

def gelu(x):
    return 0.5 * x * (1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * x**3)))
    
def gelu_derivative(x):
    s = np.sqrt(2 / np.pi) * (x + 0.044715 * x**3) 
    tanh_s = np.tanh(s)
    sech2_s = 1 - tanh_s**2 

    return 0.5 * (1 + tanh_s) + 0.5 * x * sech2_s * np.sqrt(2 / np.pi) * (1 + 0.134145 * x**2)

def softmax(x):
    shifted = x - np.max(x, axis=0, keepdims=True)
    exps = np.exp(shifted)
    return exps / np.sum(exps, axis=0, keepdims=True)


def cross_entropy_loss(y_pred, y_true):
    m = y_true.shape[0]
    loss = -np.sum(y_true * np.log(y_pred + 1e-15)) / m
    return loss

def accuracy(y_pred, y_true):
    y_pred_labels = np.argmax(y_pred, axis=1)
    y_true_labels = np.argmax(y_true, axis=1)
    return np.mean(y_pred_labels == y_true_labels)

# %%
class MLP:
    def __init__(self, layer_sizes, activations, dropout_rate=0.0):
        self.layers = []
        self.dropout_rate = dropout_rate
        for i in range(len(layer_sizes) - 1):
            # He initialization for ReLU, Xavier for Tanh
            if activations[i] == 'softmax':
                scale = 0.01  # Smaller scale for softmax layer
            elif activations[i] in ['relu', 'leaky_relu', 'gelu']:
                scale = np.sqrt(2.0 / layer_sizes[i])
            else:
                scale = np.sqrt(1.0 / layer_sizes[i])  # For Tanh/Sigmoid
            W = np.random.randn(layer_sizes[i+1], layer_sizes[i]) * scale
            b = np.zeros((layer_sizes[i+1], 1))
            self.layers.append({
                'W': W,
                'b': b,
                'activation': activations[i]
            })
    
    def forward(self, X, training=True):
        A = X.T  # (input_size, batch_size)
        cache = []
        for layer in self.layers:
            Z = layer['W'] @ A + layer['b']
            activation = layer['activation']
            if activation == 'relu':
                A = relu(Z)
            elif activation == 'leaky_relu':
                A = leaky_relu(Z)
            elif activation == 'tanh':
                A = tanh(Z)
            elif activation == 'gelu':
                A = gelu(Z)
            elif activation == 'softmax':
                A = softmax(Z)
            # Applying dropout (skip for output layer)
            if training and activation != 'softmax' and self.dropout_rate > 0:
                mask = (np.random.rand(*A.shape) < (1 - self.dropout_rate)) / (1 - self.dropout_rate)
                A *= mask
                cache.append({'Z': Z, 'A': A, 'mask': mask})
            else:
                cache.append({'Z': Z, 'A': A})
        return A.T, cache  # (batch_size, output_size), cache
    
    def backward(self, X, y_true, learning_rate, cache):
        y_pred = cache[-1]['A'].T 
        m = y_true.shape[0]
        dZ = (y_pred - y_true).T / m
        
        for i in reversed(range(len(self.layers))):
            layer = self.layers[i]
            layer_cache = cache[i]
            Z = layer_cache['Z']
            A_prev = X.T if i == 0 else cache[i-1]['A']
            
            # gradients for weights/biases
            dW = dZ @ A_prev.T
            db = np.sum(dZ, axis=1, keepdims=True)
            
            # Update parameters
            layer['W'] -= learning_rate * dW
            layer['b'] -= learning_rate * db
            
            # Propagate gradient to previous layer
            if i > 0:
                dA = self.layers[i]['W'].T @ dZ
                # Apply dropout mask if present
                if 'mask' in cache[i-1]:
                    dA *= cache[i-1]['mask']
                # Get Z from the PREVIOUS layer's cache
                Z_prev = cache[i-1]['Z'] 
                # Compute dZ using activation derivative of PREVIOUS layer
                activation = self.layers[i-1]['activation']
                if activation == 'relu':
                    dZ = dA * relu_derivative(Z_prev)  # Use Z_prev
                elif activation == 'leaky_relu':
                    dZ = dA * leaky_relu_derivative(Z_prev) 
                elif activation == 'tanh':
                    dZ = dA * tanh_derivative(Z_prev) 
                elif activation == 'gelu':
                    dZ = dA * gelu_derivative(Z_prev) 


def train_mlp(x_train, y_train, x_val, y_val, layer_sizes, activations, 
              epochs=10, batch_size=64, lr=0.01, dropout_rate=0.0,
              patience=5, delta=0.001):
    
    print(layer_sizes,activations)
    
    mlp = MLP(layer_sizes, activations, dropout_rate)
    
    train_losses, train_accs = [], []
    val_losses, val_accs = [], []
    
    best_val_loss = np.inf
    best_epoch = 0
    wait = 0  # Counter for epochs without improvement for early stopping
    best_model = None  # Store the best model state
    
    for epoch in range(epochs):
        permutation = np.random.permutation(x_train.shape[0])
        x_shuffled = x_train[permutation]
        y_shuffled = y_train[permutation]
        
        epoch_train_loss, epoch_train_acc = 0, 0
        for i in range(0, x_train.shape[0], batch_size):
            X_batch = x_shuffled[i:i+batch_size]
            y_batch = y_shuffled[i:i+batch_size]
            y_pred, cache = mlp.forward(X_batch, training=True)
            batch_loss = cross_entropy_loss(y_pred, y_batch)
            batch_acc = accuracy(y_pred, y_batch)
            epoch_train_loss += batch_loss * len(X_batch)
            epoch_train_acc += batch_acc * len(X_batch)
            mlp.backward(X_batch, y_batch, lr, cache)
        
        # Compute training metrics
        epoch_train_loss /= len(x_train)
        epoch_train_acc /= len(x_train)
        train_losses.append(epoch_train_loss)
        train_accs.append(epoch_train_acc)
        
        # Compute validation metrics
        val_pred, _ = mlp.forward(x_val, training=False)
        val_loss = cross_entropy_loss(val_pred, y_val)
        val_acc = accuracy(val_pred, y_val)
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        
        # Early stopping logic
        if val_loss < best_val_loss - delta:
            print(f"Validation loss improved from {best_val_loss:.4f} to {val_loss:.4f}")
            best_val_loss = val_loss
            best_epoch = epoch
            wait = 0
            # Save the best model weights
            best_model = [
                {'W': np.copy(layer['W']), 'b': np.copy(layer['b'])} 
                for layer in mlp.layers
            ]
        else:
            wait += 1
            if wait >= patience:
                print(f"\nEarly stopping at epoch {epoch+1} (best epoch: {best_epoch+1})")
                break  # Exit the training loop
        
        print(f"Epoch {epoch+1}/{epochs} | "
              f"Train Loss: {epoch_train_loss:.4f} | Train Acc: {epoch_train_acc:.4f} | "
              f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f} | "
              f"Patience: {wait}/{patience}")
    
    # Restore the best model weights
    if best_model is not None:
        for i, layer in enumerate(mlp.layers):
            layer['W'] = best_model[i]['W']
            layer['b'] = best_model[i]['b']
    
    return mlp, train_losses, train_accs, val_losses, val_accs

# %%
layer_sizes = [784, 128, 10]
activations = ['leaky_relu','softmax']
best_mlp, train_loss, train_acc, val_loss, val_acc = train_mlp(
    x_train, y_train, x_val, y_val, 
    layer_sizes, activations, 
    epochs=200,dropout_rate=0.2, lr=0.001,patience=5,batch_size=32
)

import matplotlib.pyplot as plt

# Plot loss curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss vs. Epochs')

# Plot accuracy curves
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy vs. Epochs')

plt.tight_layout()
plt.show()

test_pred, _ = best_mlp.forward(X_test, training=False)
test_acc = accuracy(test_pred, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# [784, 128, 10] ['leaky_relu', 'softmax']
# Validation loss improved from inf to 0.9451
# Epoch 1/200 | Train Loss: 1.4035 | Train Acc: 0.6230 | Val Loss: 0.9451 | Val Acc: 0.7082 | Patience: 0/5
# Validation loss improved from 0.9451 to 0.7377
# Epoch 2/200 | Train Loss: 0.8466 | Train Acc: 0.7228 | Val Loss: 0.7377 | Val Acc: 0.7490 | Patience: 0/5
# Validation loss improved from 0.7377 to 0.6563
# Epoch 3/200 | Train Loss: 0.7233 | Train Acc: 0.7493 | Val Loss: 0.6563 | Val Acc: 0.7686 | Patience: 0/5
# Validation loss improved from 0.6563 to 0.6083
# Epoch 4/200 | Train Loss: 0.6601 | Train Acc: 0.7669 | Val Loss: 0.6083 | Val Acc: 0.7816 | Patience: 0/5
# Validation loss improved from 0.6083 to 0.5754
# Epoch 5/200 | Train Loss: 0.6190 | Train Acc: 0.7780 | Val Loss: 0.5754 | Val Acc: 0.7933 | Patience: 0/5
# Validation loss improved from 0.5754 to 0.5498
# Epoch 6/200 | Train Loss: 0.5920 | Train Acc: 0.7879 | Val Loss: 0.5498 | Val Acc: 0.8006 | Patience: 0/5
# Validation loss improved from 0.5498 to 0.5310
# Epoch 7/200 | Train Loss: 0.5698 | Train Acc: 0.7962 | Val Loss: 0.5310 | Val Acc: 0.8061 | Patience: 0/5
# Validation loss improved from 0.5310 to 0.5141
# Epoch 8/200 | Train Loss: 0.5529 | Train Acc: 0.8012 | Val Loss: 0.5141 | Val Acc: 0.8122 | Patience: 0/5
# Validation loss improved from 0.5141 to 0.5013
# Epoch 9/200 | Train Loss: 0.5386 | Train Acc: 0.8061 | Val Loss: 0.5013 | Val Acc: 0.8174 | Patience: 0/5
# Validation loss improved from 0.5013 to 0.4901
# Epoch 10/200 | Train Loss: 0.5247 | Train Acc: 0.8100 | Val Loss: 0.4901 | Val Acc: 0.8219 | Patience: 0/5
# Validation loss improved from 0.4901 to 0.4804
# Epoch 11/200 | Train Loss: 0.5133 | Train Acc: 0.8153 | Val Loss: 0.4804 | Val Acc: 0.8266 | Patience: 0/5
# Validation loss improved from 0.4804 to 0.4723
# Epoch 12/200 | Train Loss: 0.5036 | Train Acc: 0.8189 | Val Loss: 0.4723 | Val Acc: 0.8293 | Patience: 0/5
# Validation loss improved from 0.4723 to 0.4655
# Epoch 13/200 | Train Loss: 0.4960 | Train Acc: 0.8213 | Val Loss: 0.4655 | Val Acc: 0.8317 | Patience: 0/5
# Validation loss improved from 0.4655 to 0.4582
# Epoch 14/200 | Train Loss: 0.4881 | Train Acc: 0.8250 | Val Loss: 0.4582 | Val Acc: 0.8347 | Patience: 0/5
# Validation loss improved from 0.4582 to 0.4529
# Epoch 15/200 | Train Loss: 0.4808 | Train Acc: 0.8276 | Val Loss: 0.4529 | Val Acc: 0.8367 | Patience: 0/5
# Validation loss improved from 0.4529 to 0.4474
# Epoch 16/200 | Train Loss: 0.4757 | Train Acc: 0.8297 | Val Loss: 0.4474 | Val Acc: 0.8371 | Patience: 0/5
# Validation loss improved from 0.4474 to 0.4425
# Epoch 17/200 | Train Loss: 0.4697 | Train Acc: 0.8299 | Val Loss: 0.4425 | Val Acc: 0.8403 | Patience: 0/5
# Validation loss improved from 0.4425 to 0.4387
# Epoch 18/200 | Train Loss: 0.4664 | Train Acc: 0.8317 | Val Loss: 0.4387 | Val Acc: 0.8409 | Patience: 0/5
# Validation loss improved from 0.4387 to 0.4338
# Epoch 19/200 | Train Loss: 0.4578 | Train Acc: 0.8369 | Val Loss: 0.4338 | Val Acc: 0.8429 | Patience: 0/5
# Validation loss improved from 0.4338 to 0.4304
# Epoch 20/200 | Train Loss: 0.4560 | Train Acc: 0.8385 | Val Loss: 0.4304 | Val Acc: 0.8424 | Patience: 0/5
# Validation loss improved from 0.4304 to 0.4267
# Epoch 21/200 | Train Loss: 0.4485 | Train Acc: 0.8405 | Val Loss: 0.4267 | Val Acc: 0.8438 | Patience: 0/5
# Validation loss improved from 0.4267 to 0.4240
# Epoch 22/200 | Train Loss: 0.4468 | Train Acc: 0.8396 | Val Loss: 0.4240 | Val Acc: 0.8460 | Patience: 0/5
# Validation loss improved from 0.4240 to 0.4202
# Epoch 23/200 | Train Loss: 0.4415 | Train Acc: 0.8425 | Val Loss: 0.4202 | Val Acc: 0.8473 | Patience: 0/5
# Validation loss improved from 0.4202 to 0.4177
# Epoch 24/200 | Train Loss: 0.4408 | Train Acc: 0.8429 | Val Loss: 0.4177 | Val Acc: 0.8477 | Patience: 0/5
# Validation loss improved from 0.4177 to 0.4156
# Epoch 25/200 | Train Loss: 0.4373 | Train Acc: 0.8441 | Val Loss: 0.4156 | Val Acc: 0.8493 | Patience: 0/5
# Validation loss improved from 0.4156 to 0.4126
# Epoch 26/200 | Train Loss: 0.4330 | Train Acc: 0.8465 | Val Loss: 0.4126 | Val Acc: 0.8509 | Patience: 0/5
# Validation loss improved from 0.4126 to 0.4107
# Epoch 27/200 | Train Loss: 0.4302 | Train Acc: 0.8471 | Val Loss: 0.4107 | Val Acc: 0.8501 | Patience: 0/5
# Validation loss improved from 0.4107 to 0.4082
# Epoch 28/200 | Train Loss: 0.4274 | Train Acc: 0.8491 | Val Loss: 0.4082 | Val Acc: 0.8527 | Patience: 0/5
# Validation loss improved from 0.4082 to 0.4057
# Epoch 29/200 | Train Loss: 0.4261 | Train Acc: 0.8479 | Val Loss: 0.4057 | Val Acc: 0.8534 | Patience: 0/5
# Validation loss improved from 0.4057 to 0.4045
# Epoch 30/200 | Train Loss: 0.4218 | Train Acc: 0.8508 | Val Loss: 0.4045 | Val Acc: 0.8528 | Patience: 0/5
# Validation loss improved from 0.4045 to 0.4024
# Epoch 31/200 | Train Loss: 0.4176 | Train Acc: 0.8523 | Val Loss: 0.4024 | Val Acc: 0.8545 | Patience: 0/5
# Validation loss improved from 0.4024 to 0.4006
# Epoch 32/200 | Train Loss: 0.4161 | Train Acc: 0.8525 | Val Loss: 0.4006 | Val Acc: 0.8559 | Patience: 0/5
# Validation loss improved from 0.4006 to 0.3981
# Epoch 33/200 | Train Loss: 0.4130 | Train Acc: 0.8529 | Val Loss: 0.3981 | Val Acc: 0.8551 | Patience: 0/5
# Validation loss improved from 0.3981 to 0.3963
# Epoch 34/200 | Train Loss: 0.4111 | Train Acc: 0.8534 | Val Loss: 0.3963 | Val Acc: 0.8562 | Patience: 0/5
# Validation loss improved from 0.3963 to 0.3947
# Epoch 35/200 | Train Loss: 0.4088 | Train Acc: 0.8545 | Val Loss: 0.3947 | Val Acc: 0.8578 | Patience: 0/5
# Validation loss improved from 0.3947 to 0.3929
# Epoch 36/200 | Train Loss: 0.4066 | Train Acc: 0.8554 | Val Loss: 0.3929 | Val Acc: 0.8578 | Patience: 0/5
# Validation loss improved from 0.3929 to 0.3919
# Epoch 37/200 | Train Loss: 0.4053 | Train Acc: 0.8562 | Val Loss: 0.3919 | Val Acc: 0.8578 | Patience: 0/5
# Validation loss improved from 0.3919 to 0.3908
# Epoch 38/200 | Train Loss: 0.4038 | Train Acc: 0.8564 | Val Loss: 0.3908 | Val Acc: 0.8594 | Patience: 0/5
# Validation loss improved from 0.3908 to 0.3890
# Epoch 39/200 | Train Loss: 0.4004 | Train Acc: 0.8584 | Val Loss: 0.3890 | Val Acc: 0.8588 | Patience: 0/5
# Validation loss improved from 0.3890 to 0.3874
# Epoch 40/200 | Train Loss: 0.3991 | Train Acc: 0.8571 | Val Loss: 0.3874 | Val Acc: 0.8596 | Patience: 0/5
# Validation loss improved from 0.3874 to 0.3858
# Epoch 41/200 | Train Loss: 0.3965 | Train Acc: 0.8588 | Val Loss: 0.3858 | Val Acc: 0.8610 | Patience: 0/5
# Validation loss improved from 0.3858 to 0.3844
# Epoch 42/200 | Train Loss: 0.3955 | Train Acc: 0.8578 | Val Loss: 0.3844 | Val Acc: 0.8610 | Patience: 0/5
# Validation loss improved from 0.3844 to 0.3832
# Epoch 43/200 | Train Loss: 0.3945 | Train Acc: 0.8596 | Val Loss: 0.3832 | Val Acc: 0.8612 | Patience: 0/5
# Validation loss improved from 0.3832 to 0.3820
# Epoch 44/200 | Train Loss: 0.3918 | Train Acc: 0.8600 | Val Loss: 0.3820 | Val Acc: 0.8618 | Patience: 0/5
# Validation loss improved from 0.3820 to 0.3807
# Epoch 45/200 | Train Loss: 0.3894 | Train Acc: 0.8620 | Val Loss: 0.3807 | Val Acc: 0.8629 | Patience: 0/5
# Validation loss improved from 0.3807 to 0.3796
# Epoch 46/200 | Train Loss: 0.3901 | Train Acc: 0.8610 | Val Loss: 0.3796 | Val Acc: 0.8628 | Patience: 0/5
# Validation loss improved from 0.3796 to 0.3781
# Epoch 47/200 | Train Loss: 0.3850 | Train Acc: 0.8628 | Val Loss: 0.3781 | Val Acc: 0.8633 | Patience: 0/5
# Epoch 48/200 | Train Loss: 0.3846 | Train Acc: 0.8627 | Val Loss: 0.3772 | Val Acc: 0.8650 | Patience: 1/5
# Validation loss improved from 0.3781 to 0.3759
# Epoch 49/200 | Train Loss: 0.3827 | Train Acc: 0.8638 | Val Loss: 0.3759 | Val Acc: 0.8647 | Patience: 0/5
# Epoch 50/200 | Train Loss: 0.3806 | Train Acc: 0.8642 | Val Loss: 0.3756 | Val Acc: 0.8652 | Patience: 1/5
# Validation loss improved from 0.3759 to 0.3742
# Epoch 51/200 | Train Loss: 0.3789 | Train Acc: 0.8660 | Val Loss: 0.3742 | Val Acc: 0.8649 | Patience: 0/5
# Validation loss improved from 0.3742 to 0.3728
# Epoch 52/200 | Train Loss: 0.3796 | Train Acc: 0.8656 | Val Loss: 0.3728 | Val Acc: 0.8658 | Patience: 0/5
# Epoch 53/200 | Train Loss: 0.3782 | Train Acc: 0.8654 | Val Loss: 0.3720 | Val Acc: 0.8661 | Patience: 1/5
# Validation loss improved from 0.3728 to 0.3709
# Epoch 54/200 | Train Loss: 0.3755 | Train Acc: 0.8648 | Val Loss: 0.3709 | Val Acc: 0.8661 | Patience: 0/5
# Epoch 55/200 | Train Loss: 0.3754 | Train Acc: 0.8662 | Val Loss: 0.3702 | Val Acc: 0.8662 | Patience: 1/5
# Validation loss improved from 0.3709 to 0.3689
# Epoch 56/200 | Train Loss: 0.3726 | Train Acc: 0.8674 | Val Loss: 0.3689 | Val Acc: 0.8671 | Patience: 0/5
# Epoch 57/200 | Train Loss: 0.3711 | Train Acc: 0.8675 | Val Loss: 0.3683 | Val Acc: 0.8674 | Patience: 1/5
# Validation loss improved from 0.3689 to 0.3676
# Epoch 58/200 | Train Loss: 0.3723 | Train Acc: 0.8675 | Val Loss: 0.3676 | Val Acc: 0.8688 | Patience: 0/5
# Epoch 59/200 | Train Loss: 0.3677 | Train Acc: 0.8679 | Val Loss: 0.3667 | Val Acc: 0.8685 | Patience: 1/5
# Validation loss improved from 0.3676 to 0.3659
# Epoch 60/200 | Train Loss: 0.3670 | Train Acc: 0.8694 | Val Loss: 0.3659 | Val Acc: 0.8689 | Patience: 0/5
# Epoch 61/200 | Train Loss: 0.3665 | Train Acc: 0.8702 | Val Loss: 0.3656 | Val Acc: 0.8692 | Patience: 1/5
# Validation loss improved from 0.3659 to 0.3642
# Epoch 62/200 | Train Loss: 0.3645 | Train Acc: 0.8704 | Val Loss: 0.3642 | Val Acc: 0.8685 | Patience: 0/5
# Epoch 63/200 | Train Loss: 0.3636 | Train Acc: 0.8709 | Val Loss: 0.3636 | Val Acc: 0.8703 | Patience: 1/5
# Validation loss improved from 0.3642 to 0.3628
# Epoch 64/200 | Train Loss: 0.3619 | Train Acc: 0.8715 | Val Loss: 0.3628 | Val Acc: 0.8704 | Patience: 0/5
# Epoch 65/200 | Train Loss: 0.3600 | Train Acc: 0.8721 | Val Loss: 0.3620 | Val Acc: 0.8702 | Patience: 1/5
# Validation loss improved from 0.3628 to 0.3611
# Epoch 66/200 | Train Loss: 0.3595 | Train Acc: 0.8726 | Val Loss: 0.3611 | Val Acc: 0.8698 | Patience: 0/5
# Epoch 67/200 | Train Loss: 0.3584 | Train Acc: 0.8728 | Val Loss: 0.3605 | Val Acc: 0.8702 | Patience: 1/5
# Validation loss improved from 0.3611 to 0.3597
# Epoch 68/200 | Train Loss: 0.3577 | Train Acc: 0.8725 | Val Loss: 0.3597 | Val Acc: 0.8705 | Patience: 0/5
# Epoch 69/200 | Train Loss: 0.3565 | Train Acc: 0.8726 | Val Loss: 0.3589 | Val Acc: 0.8703 | Patience: 1/5
# Epoch 70/200 | Train Loss: 0.3553 | Train Acc: 0.8732 | Val Loss: 0.3588 | Val Acc: 0.8717 | Patience: 2/5
# Validation loss improved from 0.3597 to 0.3579
# Epoch 71/200 | Train Loss: 0.3551 | Train Acc: 0.8723 | Val Loss: 0.3579 | Val Acc: 0.8716 | Patience: 0/5
# Validation loss improved from 0.3579 to 0.3568
# Epoch 72/200 | Train Loss: 0.3528 | Train Acc: 0.8739 | Val Loss: 0.3568 | Val Acc: 0.8729 | Patience: 0/5
# Epoch 73/200 | Train Loss: 0.3522 | Train Acc: 0.8740 | Val Loss: 0.3569 | Val Acc: 0.8721 | Patience: 1/5
# Epoch 74/200 | Train Loss: 0.3490 | Train Acc: 0.8763 | Val Loss: 0.3558 | Val Acc: 0.8732 | Patience: 2/5
# Validation loss improved from 0.3568 to 0.3548
# Epoch 75/200 | Train Loss: 0.3512 | Train Acc: 0.8745 | Val Loss: 0.3548 | Val Acc: 0.8726 | Patience: 0/5
# Epoch 76/200 | Train Loss: 0.3496 | Train Acc: 0.8761 | Val Loss: 0.3546 | Val Acc: 0.8728 | Patience: 1/5
# Validation loss improved from 0.3548 to 0.3538
# Epoch 77/200 | Train Loss: 0.3472 | Train Acc: 0.8766 | Val Loss: 0.3538 | Val Acc: 0.8736 | Patience: 0/5
# Epoch 78/200 | Train Loss: 0.3493 | Train Acc: 0.8753 | Val Loss: 0.3534 | Val Acc: 0.8727 | Patience: 1/5
# Validation loss improved from 0.3538 to 0.3528
# Epoch 79/200 | Train Loss: 0.3441 | Train Acc: 0.8762 | Val Loss: 0.3528 | Val Acc: 0.8740 | Patience: 0/5
# Epoch 80/200 | Train Loss: 0.3437 | Train Acc: 0.8786 | Val Loss: 0.3531 | Val Acc: 0.8724 | Patience: 1/5
# Validation loss improved from 0.3528 to 0.3517
# Epoch 81/200 | Train Loss: 0.3440 | Train Acc: 0.8774 | Val Loss: 0.3517 | Val Acc: 0.8744 | Patience: 0/5
# Epoch 82/200 | Train Loss: 0.3434 | Train Acc: 0.8773 | Val Loss: 0.3518 | Val Acc: 0.8738 | Patience: 1/5
# Epoch 83/200 | Train Loss: 0.3436 | Train Acc: 0.8784 | Val Loss: 0.3509 | Val Acc: 0.8742 | Patience: 2/5
# Epoch 84/200 | Train Loss: 0.3388 | Train Acc: 0.8798 | Val Loss: 0.3510 | Val Acc: 0.8743 | Patience: 3/5
# Validation loss improved from 0.3517 to 0.3497
# Epoch 85/200 | Train Loss: 0.3396 | Train Acc: 0.8780 | Val Loss: 0.3497 | Val Acc: 0.8748 | Patience: 0/5
# Validation loss improved from 0.3497 to 0.3487
# Epoch 86/200 | Train Loss: 0.3411 | Train Acc: 0.8788 | Val Loss: 0.3487 | Val Acc: 0.8745 | Patience: 0/5
# Epoch 87/200 | Train Loss: 0.3392 | Train Acc: 0.8785 | Val Loss: 0.3485 | Val Acc: 0.8742 | Patience: 1/5
# Epoch 88/200 | Train Loss: 0.3387 | Train Acc: 0.8779 | Val Loss: 0.3483 | Val Acc: 0.8752 | Patience: 2/5
# Validation loss improved from 0.3487 to 0.3476
# Epoch 89/200 | Train Loss: 0.3356 | Train Acc: 0.8808 | Val Loss: 0.3476 | Val Acc: 0.8742 | Patience: 0/5
# Epoch 90/200 | Train Loss: 0.3370 | Train Acc: 0.8795 | Val Loss: 0.3474 | Val Acc: 0.8752 | Patience: 1/5
# Epoch 91/200 | Train Loss: 0.3352 | Train Acc: 0.8813 | Val Loss: 0.3469 | Val Acc: 0.8752 | Patience: 2/5
# Validation loss improved from 0.3476 to 0.3464
# Epoch 92/200 | Train Loss: 0.3338 | Train Acc: 0.8819 | Val Loss: 0.3464 | Val Acc: 0.8753 | Patience: 0/5
# Epoch 93/200 | Train Loss: 0.3326 | Train Acc: 0.8816 | Val Loss: 0.3461 | Val Acc: 0.8756 | Patience: 1/5
# Validation loss improved from 0.3464 to 0.3453
# Epoch 94/200 | Train Loss: 0.3315 | Train Acc: 0.8822 | Val Loss: 0.3453 | Val Acc: 0.8750 | Patience: 0/5
# Epoch 95/200 | Train Loss: 0.3312 | Train Acc: 0.8814 | Val Loss: 0.3448 | Val Acc: 0.8761 | Patience: 1/5
# Validation loss improved from 0.3453 to 0.3442
# Epoch 96/200 | Train Loss: 0.3286 | Train Acc: 0.8824 | Val Loss: 0.3442 | Val Acc: 0.8761 | Patience: 0/5
# Epoch 97/200 | Train Loss: 0.3295 | Train Acc: 0.8825 | Val Loss: 0.3444 | Val Acc: 0.8763 | Patience: 1/5
# Epoch 98/200 | Train Loss: 0.3255 | Train Acc: 0.8851 | Val Loss: 0.3437 | Val Acc: 0.8768 | Patience: 2/5
# Validation loss improved from 0.3442 to 0.3428
# Epoch 99/200 | Train Loss: 0.3284 | Train Acc: 0.8843 | Val Loss: 0.3428 | Val Acc: 0.8775 | Patience: 0/5
# Epoch 100/200 | Train Loss: 0.3276 | Train Acc: 0.8836 | Val Loss: 0.3428 | Val Acc: 0.8772 | Patience: 1/5
# Epoch 101/200 | Train Loss: 0.3259 | Train Acc: 0.8848 | Val Loss: 0.3425 | Val Acc: 0.8763 | Patience: 2/5
# Epoch 102/200 | Train Loss: 0.3251 | Train Acc: 0.8838 | Val Loss: 0.3421 | Val Acc: 0.8779 | Patience: 3/5
# Epoch 103/200 | Train Loss: 0.3237 | Train Acc: 0.8851 | Val Loss: 0.3424 | Val Acc: 0.8769 | Patience: 4/5
# Validation loss improved from 0.3428 to 0.3417
# Epoch 104/200 | Train Loss: 0.3246 | Train Acc: 0.8836 | Val Loss: 0.3417 | Val Acc: 0.8769 | Patience: 0/5
# Epoch 105/200 | Train Loss: 0.3230 | Train Acc: 0.8841 | Val Loss: 0.3418 | Val Acc: 0.8765 | Patience: 1/5
# Epoch 106/200 | Train Loss: 0.3210 | Train Acc: 0.8854 | Val Loss: 0.3410 | Val Acc: 0.8782 | Patience: 2/5
# Validation loss improved from 0.3417 to 0.3405
# Epoch 107/200 | Train Loss: 0.3217 | Train Acc: 0.8840 | Val Loss: 0.3405 | Val Acc: 0.8777 | Patience: 0/5
# Epoch 108/200 | Train Loss: 0.3223 | Train Acc: 0.8848 | Val Loss: 0.3400 | Val Acc: 0.8778 | Patience: 1/5
# Epoch 109/200 | Train Loss: 0.3197 | Train Acc: 0.8865 | Val Loss: 0.3398 | Val Acc: 0.8787 | Patience: 2/5
# Validation loss improved from 0.3405 to 0.3392
# Epoch 110/200 | Train Loss: 0.3183 | Train Acc: 0.8858 | Val Loss: 0.3392 | Val Acc: 0.8778 | Patience: 0/5
# Epoch 111/200 | Train Loss: 0.3177 | Train Acc: 0.8869 | Val Loss: 0.3387 | Val Acc: 0.8778 | Patience: 1/5
# Epoch 112/200 | Train Loss: 0.3170 | Train Acc: 0.8866 | Val Loss: 0.3382 | Val Acc: 0.8788 | Patience: 2/5
# Validation loss improved from 0.3392 to 0.3377
# Epoch 113/200 | Train Loss: 0.3163 | Train Acc: 0.8874 | Val Loss: 0.3377 | Val Acc: 0.8787 | Patience: 0/5
# Epoch 114/200 | Train Loss: 0.3167 | Train Acc: 0.8871 | Val Loss: 0.3376 | Val Acc: 0.8790 | Patience: 1/5
# Epoch 115/200 | Train Loss: 0.3141 | Train Acc: 0.8882 | Val Loss: 0.3378 | Val Acc: 0.8778 | Patience: 2/5
# Epoch 116/200 | Train Loss: 0.3132 | Train Acc: 0.8886 | Val Loss: 0.3371 | Val Acc: 0.8796 | Patience: 3/5
# Validation loss improved from 0.3377 to 0.3367
# Epoch 117/200 | Train Loss: 0.3149 | Train Acc: 0.8874 | Val Loss: 0.3367 | Val Acc: 0.8788 | Patience: 0/5
# Epoch 118/200 | Train Loss: 0.3129 | Train Acc: 0.8899 | Val Loss: 0.3364 | Val Acc: 0.8791 | Patience: 1/5
# Epoch 119/200 | Train Loss: 0.3138 | Train Acc: 0.8877 | Val Loss: 0.3361 | Val Acc: 0.8790 | Patience: 2/5
# Epoch 120/200 | Train Loss: 0.3108 | Train Acc: 0.8888 | Val Loss: 0.3357 | Val Acc: 0.8784 | Patience: 3/5
# Validation loss improved from 0.3367 to 0.3353
# Epoch 121/200 | Train Loss: 0.3141 | Train Acc: 0.8884 | Val Loss: 0.3353 | Val Acc: 0.8791 | Patience: 0/5
# Epoch 122/200 | Train Loss: 0.3110 | Train Acc: 0.8892 | Val Loss: 0.3353 | Val Acc: 0.8782 | Patience: 1/5
# Epoch 123/200 | Train Loss: 0.3103 | Train Acc: 0.8889 | Val Loss: 0.3349 | Val Acc: 0.8789 | Patience: 2/5
# Epoch 124/200 | Train Loss: 0.3099 | Train Acc: 0.8892 | Val Loss: 0.3350 | Val Acc: 0.8794 | Patience: 3/5
# Epoch 125/200 | Train Loss: 0.3089 | Train Acc: 0.8896 | Val Loss: 0.3345 | Val Acc: 0.8780 | Patience: 4/5
# Validation loss improved from 0.3353 to 0.3338
# Epoch 126/200 | Train Loss: 0.3079 | Train Acc: 0.8896 | Val Loss: 0.3338 | Val Acc: 0.8790 | Patience: 0/5
# Epoch 127/200 | Train Loss: 0.3097 | Train Acc: 0.8896 | Val Loss: 0.3341 | Val Acc: 0.8793 | Patience: 1/5
# Epoch 128/200 | Train Loss: 0.3079 | Train Acc: 0.8904 | Val Loss: 0.3340 | Val Acc: 0.8792 | Patience: 2/5
# Epoch 129/200 | Train Loss: 0.3048 | Train Acc: 0.8916 | Val Loss: 0.3346 | Val Acc: 0.8789 | Patience: 3/5
# Epoch 130/200 | Train Loss: 0.3055 | Train Acc: 0.8914 | Val Loss: 0.3340 | Val Acc: 0.8795 | Patience: 4/5
#
# Early stopping at epoch 131 (best epoch: 126)
# Test Accuracy: 0.8796

# %%
layer_sizes = [784, 400, 250, 100, 10]
activations = ['relu', 'relu', 'relu', 'softmax']
best_mlp, train_loss, train_acc, val_loss, val_acc = train_mlp(
    x_train, y_train, x_val, y_val, 
    layer_sizes, activations, 
    epochs=200,dropout_rate=0.2, lr=0.001,patience=5,batch_size=32
)

import matplotlib.pyplot as plt

# Plot loss curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss vs. Epochs')

# Plot accuracy curves
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy vs. Epochs')

plt.tight_layout()
plt.show()

test_pred, _ = best_mlp.forward(X_test, training=False)
test_acc = accuracy(test_pred, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# [784, 400, 250, 100, 10] ['relu', 'relu', 'relu', 'softmax']
# Validation loss improved from inf to 0.9693
# Epoch 1/200 | Train Loss: 1.5948 | Train Acc: 0.5060 | Val Loss: 0.9693 | Val Acc: 0.6894 | Patience: 0/5
# Validation loss improved from 0.9693 to 0.7124
# Epoch 2/200 | Train Loss: 0.9344 | Train Acc: 0.6739 | Val Loss: 0.7124 | Val Acc: 0.7446 | Patience: 0/5
# Validation loss improved from 0.7124 to 0.6338
# Epoch 3/200 | Train Loss: 0.7875 | Train Acc: 0.7175 | Val Loss: 0.6338 | Val Acc: 0.7685 | Patience: 0/5
# Validation loss improved from 0.6338 to 0.5891
# Epoch 4/200 | Train Loss: 0.7202 | Train Acc: 0.7380 | Val Loss: 0.5891 | Val Acc: 0.7793 | Patience: 0/5
# Validation loss improved from 0.5891 to 0.5578
# Epoch 5/200 | Train Loss: 0.6755 | Train Acc: 0.7528 | Val Loss: 0.5578 | Val Acc: 0.7911 | Patience: 0/5
# Validation loss improved from 0.5578 to 0.5352
# Epoch 6/200 | Train Loss: 0.6413 | Train Acc: 0.7663 | Val Loss: 0.5352 | Val Acc: 0.7958 | Patience: 0/5
# Validation loss improved from 0.5352 to 0.5149
# Epoch 7/200 | Train Loss: 0.6173 | Train Acc: 0.7742 | Val Loss: 0.5149 | Val Acc: 0.8074 | Patience: 0/5
# Validation loss improved from 0.5149 to 0.5012
# Epoch 8/200 | Train Loss: 0.6025 | Train Acc: 0.7798 | Val Loss: 0.5012 | Val Acc: 0.8125 | Patience: 0/5
# Validation loss improved from 0.5012 to 0.4880
# Epoch 9/200 | Train Loss: 0.5810 | Train Acc: 0.7893 | Val Loss: 0.4880 | Val Acc: 0.8174 | Patience: 0/5
# Validation loss improved from 0.4880 to 0.4763
# Epoch 10/200 | Train Loss: 0.5661 | Train Acc: 0.7940 | Val Loss: 0.4763 | Val Acc: 0.8231 | Patience: 0/5
# Validation loss improved from 0.4763 to 0.4647
# Epoch 11/200 | Train Loss: 0.5517 | Train Acc: 0.7990 | Val Loss: 0.4647 | Val Acc: 0.8264 | Patience: 0/5
# Validation loss improved from 0.4647 to 0.4564
# Epoch 12/200 | Train Loss: 0.5421 | Train Acc: 0.8031 | Val Loss: 0.4564 | Val Acc: 0.8315 | Patience: 0/5
# Validation loss improved from 0.4564 to 0.4496
# Epoch 13/200 | Train Loss: 0.5358 | Train Acc: 0.8064 | Val Loss: 0.4496 | Val Acc: 0.8331 | Patience: 0/5
# Validation loss improved from 0.4496 to 0.4427
# Epoch 14/200 | Train Loss: 0.5230 | Train Acc: 0.8124 | Val Loss: 0.4427 | Val Acc: 0.8357 | Patience: 0/5
# Validation loss improved from 0.4427 to 0.4371
# Epoch 15/200 | Train Loss: 0.5108 | Train Acc: 0.8150 | Val Loss: 0.4371 | Val Acc: 0.8374 | Patience: 0/5
# Validation loss improved from 0.4371 to 0.4326
# Epoch 16/200 | Train Loss: 0.5049 | Train Acc: 0.8161 | Val Loss: 0.4326 | Val Acc: 0.8406 | Patience: 0/5
# Validation loss improved from 0.4326 to 0.4259
# Epoch 17/200 | Train Loss: 0.4979 | Train Acc: 0.8198 | Val Loss: 0.4259 | Val Acc: 0.8425 | Patience: 0/5
# Validation loss improved from 0.4259 to 0.4204
# Epoch 18/200 | Train Loss: 0.4903 | Train Acc: 0.8229 | Val Loss: 0.4204 | Val Acc: 0.8448 | Patience: 0/5
# Validation loss improved from 0.4204 to 0.4154
# Epoch 19/200 | Train Loss: 0.4845 | Train Acc: 0.8245 | Val Loss: 0.4154 | Val Acc: 0.8481 | Patience: 0/5
# Validation loss improved from 0.4154 to 0.4136
# Epoch 20/200 | Train Loss: 0.4786 | Train Acc: 0.8276 | Val Loss: 0.4136 | Val Acc: 0.8481 | Patience: 0/5
# Validation loss improved from 0.4136 to 0.4074
# Epoch 21/200 | Train Loss: 0.4720 | Train Acc: 0.8290 | Val Loss: 0.4074 | Val Acc: 0.8512 | Patience: 0/5
# Validation loss improved from 0.4074 to 0.4053
# Epoch 22/200 | Train Loss: 0.4689 | Train Acc: 0.8289 | Val Loss: 0.4053 | Val Acc: 0.8502 | Patience: 0/5
# Validation loss improved from 0.4053 to 0.4029
# Epoch 23/200 | Train Loss: 0.4653 | Train Acc: 0.8326 | Val Loss: 0.4029 | Val Acc: 0.8520 | Patience: 0/5
# Validation loss improved from 0.4029 to 0.3981
# Epoch 24/200 | Train Loss: 0.4610 | Train Acc: 0.8334 | Val Loss: 0.3981 | Val Acc: 0.8542 | Patience: 0/5
# Epoch 25/200 | Train Loss: 0.4597 | Train Acc: 0.8347 | Val Loss: 0.3976 | Val Acc: 0.8547 | Patience: 1/5
# Validation loss improved from 0.3981 to 0.3962
# Epoch 26/200 | Train Loss: 0.4542 | Train Acc: 0.8370 | Val Loss: 0.3962 | Val Acc: 0.8550 | Patience: 0/5
# Validation loss improved from 0.3962 to 0.3910
# Epoch 27/200 | Train Loss: 0.4496 | Train Acc: 0.8383 | Val Loss: 0.3910 | Val Acc: 0.8568 | Patience: 0/5
# Validation loss improved from 0.3910 to 0.3889
# Epoch 28/200 | Train Loss: 0.4452 | Train Acc: 0.8404 | Val Loss: 0.3889 | Val Acc: 0.8578 | Patience: 0/5
# Validation loss improved from 0.3889 to 0.3862
# Epoch 29/200 | Train Loss: 0.4417 | Train Acc: 0.8414 | Val Loss: 0.3862 | Val Acc: 0.8595 | Patience: 0/5
# Validation loss improved from 0.3862 to 0.3843
# Epoch 30/200 | Train Loss: 0.4366 | Train Acc: 0.8429 | Val Loss: 0.3843 | Val Acc: 0.8596 | Patience: 0/5
# Validation loss improved from 0.3843 to 0.3805
# Epoch 31/200 | Train Loss: 0.4326 | Train Acc: 0.8457 | Val Loss: 0.3805 | Val Acc: 0.8603 | Patience: 0/5
# Validation loss improved from 0.3805 to 0.3785
# Epoch 32/200 | Train Loss: 0.4321 | Train Acc: 0.8428 | Val Loss: 0.3785 | Val Acc: 0.8613 | Patience: 0/5
# Validation loss improved from 0.3785 to 0.3762
# Epoch 33/200 | Train Loss: 0.4265 | Train Acc: 0.8462 | Val Loss: 0.3762 | Val Acc: 0.8609 | Patience: 0/5
# Validation loss improved from 0.3762 to 0.3749
# Epoch 34/200 | Train Loss: 0.4252 | Train Acc: 0.8461 | Val Loss: 0.3749 | Val Acc: 0.8625 | Patience: 0/5
# Validation loss improved from 0.3749 to 0.3737
# Epoch 35/200 | Train Loss: 0.4234 | Train Acc: 0.8472 | Val Loss: 0.3737 | Val Acc: 0.8628 | Patience: 0/5
# Validation loss improved from 0.3737 to 0.3705
# Epoch 36/200 | Train Loss: 0.4197 | Train Acc: 0.8486 | Val Loss: 0.3705 | Val Acc: 0.8637 | Patience: 0/5
# Epoch 37/200 | Train Loss: 0.4170 | Train Acc: 0.8510 | Val Loss: 0.3712 | Val Acc: 0.8628 | Patience: 1/5
# Epoch 38/200 | Train Loss: 0.4142 | Train Acc: 0.8507 | Val Loss: 0.3696 | Val Acc: 0.8630 | Patience: 2/5
# Validation loss improved from 0.3705 to 0.3670
# Epoch 39/200 | Train Loss: 0.4147 | Train Acc: 0.8501 | Val Loss: 0.3670 | Val Acc: 0.8637 | Patience: 0/5
# Validation loss improved from 0.3670 to 0.3653
# Epoch 40/200 | Train Loss: 0.4115 | Train Acc: 0.8528 | Val Loss: 0.3653 | Val Acc: 0.8660 | Patience: 0/5
# Validation loss improved from 0.3653 to 0.3640
# Epoch 41/200 | Train Loss: 0.4062 | Train Acc: 0.8529 | Val Loss: 0.3640 | Val Acc: 0.8652 | Patience: 0/5
# Epoch 42/200 | Train Loss: 0.4072 | Train Acc: 0.8522 | Val Loss: 0.3649 | Val Acc: 0.8649 | Patience: 1/5
# Validation loss improved from 0.3640 to 0.3612
# Epoch 43/200 | Train Loss: 0.4011 | Train Acc: 0.8548 | Val Loss: 0.3612 | Val Acc: 0.8668 | Patience: 0/5
# Epoch 44/200 | Train Loss: 0.4022 | Train Acc: 0.8564 | Val Loss: 0.3605 | Val Acc: 0.8662 | Patience: 1/5
# Validation loss improved from 0.3612 to 0.3580
# Epoch 45/200 | Train Loss: 0.3976 | Train Acc: 0.8568 | Val Loss: 0.3580 | Val Acc: 0.8687 | Patience: 0/5
# Epoch 46/200 | Train Loss: 0.3971 | Train Acc: 0.8569 | Val Loss: 0.3571 | Val Acc: 0.8688 | Patience: 1/5
# Validation loss improved from 0.3580 to 0.3558
# Epoch 47/200 | Train Loss: 0.3948 | Train Acc: 0.8567 | Val Loss: 0.3558 | Val Acc: 0.8686 | Patience: 0/5
# Epoch 48/200 | Train Loss: 0.3910 | Train Acc: 0.8585 | Val Loss: 0.3554 | Val Acc: 0.8692 | Patience: 1/5
# Validation loss improved from 0.3558 to 0.3538
# Epoch 49/200 | Train Loss: 0.3942 | Train Acc: 0.8590 | Val Loss: 0.3538 | Val Acc: 0.8692 | Patience: 0/5
# Epoch 50/200 | Train Loss: 0.3908 | Train Acc: 0.8582 | Val Loss: 0.3531 | Val Acc: 0.8698 | Patience: 1/5
# Validation loss improved from 0.3538 to 0.3520
# Epoch 51/200 | Train Loss: 0.3883 | Train Acc: 0.8598 | Val Loss: 0.3520 | Val Acc: 0.8690 | Patience: 0/5
# Validation loss improved from 0.3520 to 0.3510
# Epoch 52/200 | Train Loss: 0.3839 | Train Acc: 0.8602 | Val Loss: 0.3510 | Val Acc: 0.8708 | Patience: 0/5
# Epoch 53/200 | Train Loss: 0.3824 | Train Acc: 0.8628 | Val Loss: 0.3507 | Val Acc: 0.8694 | Patience: 1/5
# Validation loss improved from 0.3510 to 0.3489
# Epoch 54/200 | Train Loss: 0.3840 | Train Acc: 0.8602 | Val Loss: 0.3489 | Val Acc: 0.8712 | Patience: 0/5
# Validation loss improved from 0.3489 to 0.3472
# Epoch 55/200 | Train Loss: 0.3818 | Train Acc: 0.8622 | Val Loss: 0.3472 | Val Acc: 0.8713 | Patience: 0/5
# Epoch 56/200 | Train Loss: 0.3792 | Train Acc: 0.8617 | Val Loss: 0.3475 | Val Acc: 0.8709 | Patience: 1/5
# Validation loss improved from 0.3472 to 0.3459
# Epoch 57/200 | Train Loss: 0.3772 | Train Acc: 0.8642 | Val Loss: 0.3459 | Val Acc: 0.8715 | Patience: 0/5
# Validation loss improved from 0.3459 to 0.3449
# Epoch 58/200 | Train Loss: 0.3740 | Train Acc: 0.8649 | Val Loss: 0.3449 | Val Acc: 0.8711 | Patience: 0/5
# Validation loss improved from 0.3449 to 0.3436
# Epoch 59/200 | Train Loss: 0.3741 | Train Acc: 0.8635 | Val Loss: 0.3436 | Val Acc: 0.8727 | Patience: 0/5
# Epoch 60/200 | Train Loss: 0.3719 | Train Acc: 0.8670 | Val Loss: 0.3434 | Val Acc: 0.8714 | Patience: 1/5
# Validation loss improved from 0.3436 to 0.3422
# Epoch 61/200 | Train Loss: 0.3710 | Train Acc: 0.8656 | Val Loss: 0.3422 | Val Acc: 0.8726 | Patience: 0/5
# Epoch 62/200 | Train Loss: 0.3714 | Train Acc: 0.8651 | Val Loss: 0.3414 | Val Acc: 0.8732 | Patience: 1/5
# Validation loss improved from 0.3422 to 0.3410
# Epoch 63/200 | Train Loss: 0.3685 | Train Acc: 0.8680 | Val Loss: 0.3410 | Val Acc: 0.8728 | Patience: 0/5
# Validation loss improved from 0.3410 to 0.3397
# Epoch 64/200 | Train Loss: 0.3658 | Train Acc: 0.8667 | Val Loss: 0.3397 | Val Acc: 0.8735 | Patience: 0/5
# Epoch 65/200 | Train Loss: 0.3648 | Train Acc: 0.8674 | Val Loss: 0.3421 | Val Acc: 0.8715 | Patience: 1/5
# Validation loss improved from 0.3397 to 0.3382
# Epoch 66/200 | Train Loss: 0.3658 | Train Acc: 0.8676 | Val Loss: 0.3382 | Val Acc: 0.8744 | Patience: 0/5
# Validation loss improved from 0.3382 to 0.3370
# Epoch 67/200 | Train Loss: 0.3620 | Train Acc: 0.8682 | Val Loss: 0.3370 | Val Acc: 0.8743 | Patience: 0/5
# Epoch 68/200 | Train Loss: 0.3598 | Train Acc: 0.8695 | Val Loss: 0.3365 | Val Acc: 0.8741 | Patience: 1/5
# Epoch 69/200 | Train Loss: 0.3592 | Train Acc: 0.8712 | Val Loss: 0.3366 | Val Acc: 0.8749 | Patience: 2/5
# Epoch 70/200 | Train Loss: 0.3604 | Train Acc: 0.8688 | Val Loss: 0.3367 | Val Acc: 0.8745 | Patience: 3/5
# Epoch 71/200 | Train Loss: 0.3578 | Train Acc: 0.8711 | Val Loss: 0.3365 | Val Acc: 0.8753 | Patience: 4/5
# Validation loss improved from 0.3370 to 0.3338
# Epoch 72/200 | Train Loss: 0.3543 | Train Acc: 0.8716 | Val Loss: 0.3338 | Val Acc: 0.8762 | Patience: 0/5
# Epoch 73/200 | Train Loss: 0.3519 | Train Acc: 0.8727 | Val Loss: 0.3340 | Val Acc: 0.8771 | Patience: 1/5
# Epoch 74/200 | Train Loss: 0.3540 | Train Acc: 0.8714 | Val Loss: 0.3328 | Val Acc: 0.8774 | Patience: 2/5
# Validation loss improved from 0.3338 to 0.3322
# Epoch 75/200 | Train Loss: 0.3505 | Train Acc: 0.8726 | Val Loss: 0.3322 | Val Acc: 0.8763 | Patience: 0/5
# Epoch 76/200 | Train Loss: 0.3520 | Train Acc: 0.8719 | Val Loss: 0.3314 | Val Acc: 0.8771 | Patience: 1/5
# Epoch 77/200 | Train Loss: 0.3500 | Train Acc: 0.8730 | Val Loss: 0.3321 | Val Acc: 0.8773 | Patience: 2/5
# Validation loss improved from 0.3322 to 0.3303
# Epoch 78/200 | Train Loss: 0.3502 | Train Acc: 0.8734 | Val Loss: 0.3303 | Val Acc: 0.8769 | Patience: 0/5
# Epoch 79/200 | Train Loss: 0.3469 | Train Acc: 0.8740 | Val Loss: 0.3306 | Val Acc: 0.8758 | Patience: 1/5
# Validation loss improved from 0.3303 to 0.3288
# Epoch 80/200 | Train Loss: 0.3457 | Train Acc: 0.8729 | Val Loss: 0.3288 | Val Acc: 0.8780 | Patience: 0/5
# Epoch 81/200 | Train Loss: 0.3465 | Train Acc: 0.8743 | Val Loss: 0.3286 | Val Acc: 0.8782 | Patience: 1/5
# Validation loss improved from 0.3288 to 0.3274
# Epoch 82/200 | Train Loss: 0.3426 | Train Acc: 0.8743 | Val Loss: 0.3274 | Val Acc: 0.8792 | Patience: 0/5
# Epoch 83/200 | Train Loss: 0.3424 | Train Acc: 0.8758 | Val Loss: 0.3270 | Val Acc: 0.8794 | Patience: 1/5
# Epoch 84/200 | Train Loss: 0.3411 | Train Acc: 0.8761 | Val Loss: 0.3270 | Val Acc: 0.8771 | Patience: 2/5
# Epoch 85/200 | Train Loss: 0.3412 | Train Acc: 0.8772 | Val Loss: 0.3267 | Val Acc: 0.8789 | Patience: 3/5
# Validation loss improved from 0.3274 to 0.3254
# Epoch 86/200 | Train Loss: 0.3396 | Train Acc: 0.8780 | Val Loss: 0.3254 | Val Acc: 0.8798 | Patience: 0/5
# Epoch 87/200 | Train Loss: 0.3397 | Train Acc: 0.8781 | Val Loss: 0.3260 | Val Acc: 0.8788 | Patience: 1/5
# Epoch 88/200 | Train Loss: 0.3352 | Train Acc: 0.8784 | Val Loss: 0.3247 | Val Acc: 0.8800 | Patience: 2/5
# Validation loss improved from 0.3254 to 0.3237
# Epoch 89/200 | Train Loss: 0.3376 | Train Acc: 0.8781 | Val Loss: 0.3237 | Val Acc: 0.8806 | Patience: 0/5
# Epoch 90/200 | Train Loss: 0.3339 | Train Acc: 0.8770 | Val Loss: 0.3235 | Val Acc: 0.8800 | Patience: 1/5
# Epoch 91/200 | Train Loss: 0.3340 | Train Acc: 0.8785 | Val Loss: 0.3236 | Val Acc: 0.8796 | Patience: 2/5
# Validation loss improved from 0.3237 to 0.3226
# Epoch 92/200 | Train Loss: 0.3349 | Train Acc: 0.8789 | Val Loss: 0.3226 | Val Acc: 0.8817 | Patience: 0/5
# Validation loss improved from 0.3226 to 0.3214
# Epoch 93/200 | Train Loss: 0.3327 | Train Acc: 0.8798 | Val Loss: 0.3214 | Val Acc: 0.8819 | Patience: 0/5
# Epoch 94/200 | Train Loss: 0.3295 | Train Acc: 0.8794 | Val Loss: 0.3223 | Val Acc: 0.8808 | Patience: 1/5
# Epoch 95/200 | Train Loss: 0.3300 | Train Acc: 0.8796 | Val Loss: 0.3210 | Val Acc: 0.8815 | Patience: 2/5
# Epoch 100/200 | Train Loss: 0.3241 | Train Acc: 0.8822 | Val Loss: 0.3210 | Val Acc: 0.8823 | Patience: 3/5
# Validation loss improved from 0.3196 to 0.3174
# Epoch 101/200 | Train Loss: 0.3244 | Train Acc: 0.8830 | Val Loss: 0.3174 | Val Acc: 0.8832 | Patience: 0/5
# Epoch 102/200 | Train Loss: 0.3243 | Train Acc: 0.8811 | Val Loss: 0.3179 | Val Acc: 0.8839 | Patience: 1/5
# Epoch 103/200 | Train Loss: 0.3211 | Train Acc: 0.8835 | Val Loss: 0.3191 | Val Acc: 0.8825 | Patience: 2/5
# Epoch 104/200 | Train Loss: 0.3212 | Train Acc: 0.8822 | Val Loss: 0.3168 | Val Acc: 0.8840 | Patience: 3/5
# Epoch 105/200 | Train Loss: 0.3205 | Train Acc: 0.8832 | Val Loss: 0.3166 | Val Acc: 0.8828 | Patience: 4/5
#
# Early stopping at epoch 106 (best epoch: 101)
# Test Accuracy: 0.8855

# %%
layer_sizes = [784, 400, 250, 100, 10]
activations = ['gelu', 'gelu', 'gelu', 'softmax']
best_mlp, train_loss, train_acc, val_loss, val_acc = train_mlp(
    x_train, y_train, x_val, y_val, 
    layer_sizes, activations, 
    epochs=200,dropout_rate=0.2, lr=0.001,patience=5,batch_size=32
)

import matplotlib.pyplot as plt

# Plot loss curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss vs. Epochs')

# Plot accuracy curves
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy vs. Epochs')

plt.tight_layout()
plt.show()

test_pred, _ = best_mlp.forward(X_test, training=False)
test_acc = accuracy(test_pred, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# [784, 400, 250, 100, 10] ['gelu', 'gelu', 'gelu', 'softmax']
# Validation loss improved from inf to 0.9552
# Epoch 1/200 | Train Loss: 1.5978 | Train Acc: 0.5096 | Val Loss: 0.9552 | Val Acc: 0.6949 | Patience: 0/5
# Validation loss improved from 0.9552 to 0.7052
# Epoch 2/200 | Train Loss: 0.9177 | Train Acc: 0.6770 | Val Loss: 0.7052 | Val Acc: 0.7404 | Patience: 0/5
# Validation loss improved from 0.7052 to 0.6312
# Epoch 3/200 | Train Loss: 0.7752 | Train Acc: 0.7176 | Val Loss: 0.6312 | Val Acc: 0.7591 | Patience: 0/5
# Validation loss improved from 0.6312 to 0.5886
# Epoch 4/200 | Train Loss: 0.7117 | Train Acc: 0.7384 | Val Loss: 0.5886 | Val Acc: 0.7711 | Patience: 0/5
# Validation loss improved from 0.5886 to 0.5610
# Epoch 5/200 | Train Loss: 0.6697 | Train Acc: 0.7518 | Val Loss: 0.5610 | Val Acc: 0.7811 | Patience: 0/5
# Validation loss improved from 0.5610 to 0.5374
# Epoch 6/200 | Train Loss: 0.6388 | Train Acc: 0.7644 | Val Loss: 0.5374 | Val Acc: 0.7905 | Patience: 0/5
# Validation loss improved from 0.5374 to 0.5182
# Epoch 7/200 | Train Loss: 0.6112 | Train Acc: 0.7758 | Val Loss: 0.5182 | Val Acc: 0.7980 | Patience: 0/5
# Validation loss improved from 0.5182 to 0.5029
# Epoch 8/200 | Train Loss: 0.5905 | Train Acc: 0.7813 | Val Loss: 0.5029 | Val Acc: 0.8026 | Patience: 0/5
# Validation loss improved from 0.5029 to 0.4926
# Epoch 9/200 | Train Loss: 0.5786 | Train Acc: 0.7879 | Val Loss: 0.4926 | Val Acc: 0.8102 | Patience: 0/5
# Validation loss improved from 0.4926 to 0.4777
# Epoch 10/200 | Train Loss: 0.5635 | Train Acc: 0.7942 | Val Loss: 0.4777 | Val Acc: 0.8153 | Patience: 0/5
# Validation loss improved from 0.4777 to 0.4676
# Epoch 11/200 | Train Loss: 0.5509 | Train Acc: 0.7989 | Val Loss: 0.4676 | Val Acc: 0.8210 | Patience: 0/5
# Validation loss improved from 0.4676 to 0.4563
# Epoch 12/200 | Train Loss: 0.5394 | Train Acc: 0.8046 | Val Loss: 0.4563 | Val Acc: 0.8256 | Patience: 0/5
# Validation loss improved from 0.4563 to 0.4519
# Epoch 13/200 | Train Loss: 0.5271 | Train Acc: 0.8101 | Val Loss: 0.4519 | Val Acc: 0.8275 | Patience: 0/5
# Validation loss improved from 0.4519 to 0.4412
# Epoch 14/200 | Train Loss: 0.5149 | Train Acc: 0.8116 | Val Loss: 0.4412 | Val Acc: 0.8321 | Patience: 0/5
# Validation loss improved from 0.4412 to 0.4331
# Epoch 15/200 | Train Loss: 0.5090 | Train Acc: 0.8170 | Val Loss: 0.4331 | Val Acc: 0.8348 | Patience: 0/5
# Validation loss improved from 0.4331 to 0.4280
# Epoch 16/200 | Train Loss: 0.4986 | Train Acc: 0.8214 | Val Loss: 0.4280 | Val Acc: 0.8375 | Patience: 0/5
# Validation loss improved from 0.4280 to 0.4234
# Epoch 17/200 | Train Loss: 0.4921 | Train Acc: 0.8226 | Val Loss: 0.4234 | Val Acc: 0.8413 | Patience: 0/5
# Validation loss improved from 0.4234 to 0.4177
# Epoch 18/200 | Train Loss: 0.4825 | Train Acc: 0.8271 | Val Loss: 0.4177 | Val Acc: 0.8421 | Patience: 0/5
# Validation loss improved from 0.4177 to 0.4156
# Epoch 19/200 | Train Loss: 0.4774 | Train Acc: 0.8283 | Val Loss: 0.4156 | Val Acc: 0.8440 | Patience: 0/5
# Validation loss improved from 0.4156 to 0.4107
# Epoch 20/200 | Train Loss: 0.4727 | Train Acc: 0.8297 | Val Loss: 0.4107 | Val Acc: 0.8480 | Patience: 0/5
# Validation loss improved from 0.4107 to 0.4019
# Epoch 21/200 | Train Loss: 0.4654 | Train Acc: 0.8332 | Val Loss: 0.4019 | Val Acc: 0.8500 | Patience: 0/5
# Validation loss improved from 0.4019 to 0.4004
# Epoch 22/200 | Train Loss: 0.4626 | Train Acc: 0.8330 | Val Loss: 0.4004 | Val Acc: 0.8518 | Patience: 0/5
# Epoch 23/200 | Train Loss: 0.4593 | Train Acc: 0.8337 | Val Loss: 0.4002 | Val Acc: 0.8518 | Patience: 1/5
# Validation loss improved from 0.4004 to 0.3935
# Epoch 24/200 | Train Loss: 0.4549 | Train Acc: 0.8368 | Val Loss: 0.3935 | Val Acc: 0.8552 | Patience: 0/5
# Epoch 25/200 | Train Loss: 0.4493 | Train Acc: 0.8380 | Val Loss: 0.3929 | Val Acc: 0.8551 | Patience: 1/5
# Validation loss improved from 0.3935 to 0.3878
# Epoch 26/200 | Train Loss: 0.4434 | Train Acc: 0.8409 | Val Loss: 0.3878 | Val Acc: 0.8569 | Patience: 0/5
# Validation loss improved from 0.3878 to 0.3846
# Epoch 27/200 | Train Loss: 0.4383 | Train Acc: 0.8421 | Val Loss: 0.3846 | Val Acc: 0.8577 | Patience: 0/5
# Validation loss improved from 0.3846 to 0.3822
# Epoch 28/200 | Train Loss: 0.4363 | Train Acc: 0.8410 | Val Loss: 0.3822 | Val Acc: 0.8587 | Patience: 0/5
# Validation loss improved from 0.3822 to 0.3805
# Epoch 29/200 | Train Loss: 0.4335 | Train Acc: 0.8450 | Val Loss: 0.3805 | Val Acc: 0.8598 | Patience: 0/5
# Validation loss improved from 0.3805 to 0.3769
# Epoch 30/200 | Train Loss: 0.4288 | Train Acc: 0.8447 | Val Loss: 0.3769 | Val Acc: 0.8618 | Patience: 0/5
# Validation loss improved from 0.3769 to 0.3742
# Epoch 31/200 | Train Loss: 0.4262 | Train Acc: 0.8471 | Val Loss: 0.3742 | Val Acc: 0.8632 | Patience: 0/5
# Epoch 32/200 | Train Loss: 0.4231 | Train Acc: 0.8474 | Val Loss: 0.3734 | Val Acc: 0.8627 | Patience: 1/5
# Validation loss improved from 0.3742 to 0.3714
# Epoch 33/200 | Train Loss: 0.4156 | Train Acc: 0.8500 | Val Loss: 0.3714 | Val Acc: 0.8642 | Patience: 0/5
# Validation loss improved from 0.3714 to 0.3694
# Epoch 34/200 | Train Loss: 0.4180 | Train Acc: 0.8508 | Val Loss: 0.3694 | Val Acc: 0.8650 | Patience: 0/5
# Validation loss improved from 0.3694 to 0.3677
# Epoch 35/200 | Train Loss: 0.4156 | Train Acc: 0.8516 | Val Loss: 0.3677 | Val Acc: 0.8655 | Patience: 0/5
# Validation loss improved from 0.3677 to 0.3662
# Epoch 36/200 | Train Loss: 0.4094 | Train Acc: 0.8524 | Val Loss: 0.3662 | Val Acc: 0.8658 | Patience: 0/5
# Validation loss improved from 0.3662 to 0.3639
# Epoch 37/200 | Train Loss: 0.4081 | Train Acc: 0.8540 | Val Loss: 0.3639 | Val Acc: 0.8666 | Patience: 0/5
# Validation loss improved from 0.3639 to 0.3628
# Epoch 38/200 | Train Loss: 0.4032 | Train Acc: 0.8535 | Val Loss: 0.3628 | Val Acc: 0.8691 | Patience: 0/5
# Validation loss improved from 0.3628 to 0.3594
# Epoch 39/200 | Train Loss: 0.4041 | Train Acc: 0.8544 | Val Loss: 0.3594 | Val Acc: 0.8694 | Patience: 0/5
# Epoch 40/200 | Train Loss: 0.4000 | Train Acc: 0.8566 | Val Loss: 0.3586 | Val Acc: 0.8695 | Patience: 1/5
# Validation loss improved from 0.3594 to 0.3563
# Epoch 41/200 | Train Loss: 0.3959 | Train Acc: 0.8562 | Val Loss: 0.3563 | Val Acc: 0.8690 | Patience: 0/5
# Epoch 42/200 | Train Loss: 0.3960 | Train Acc: 0.8581 | Val Loss: 0.3563 | Val Acc: 0.8697 | Patience: 1/5
# Epoch 43/200 | Train Loss: 0.3885 | Train Acc: 0.8589 | Val Loss: 0.3557 | Val Acc: 0.8699 | Patience: 2/5
# Validation loss improved from 0.3563 to 0.3522
# Epoch 44/200 | Train Loss: 0.3919 | Train Acc: 0.8581 | Val Loss: 0.3522 | Val Acc: 0.8714 | Patience: 0/5
# Epoch 45/200 | Train Loss: 0.3909 | Train Acc: 0.8592 | Val Loss: 0.3513 | Val Acc: 0.8720 | Patience: 1/5
# Validation loss improved from 0.3522 to 0.3507
# Epoch 46/200 | Train Loss: 0.3859 | Train Acc: 0.8613 | Val Loss: 0.3507 | Val Acc: 0.8714 | Patience: 0/5
# Validation loss improved from 0.3507 to 0.3484
# Epoch 47/200 | Train Loss: 0.3834 | Train Acc: 0.8619 | Val Loss: 0.3484 | Val Acc: 0.8728 | Patience: 0/5
# Epoch 48/200 | Train Loss: 0.3829 | Train Acc: 0.8620 | Val Loss: 0.3479 | Val Acc: 0.8736 | Patience: 1/5
# Validation loss improved from 0.3484 to 0.3467
# Epoch 49/200 | Train Loss: 0.3803 | Train Acc: 0.8619 | Val Loss: 0.3467 | Val Acc: 0.8738 | Patience: 0/5
# Validation loss improved from 0.3467 to 0.3452
# Epoch 50/200 | Train Loss: 0.3822 | Train Acc: 0.8621 | Val Loss: 0.3452 | Val Acc: 0.8756 | Patience: 0/5
# Epoch 51/200 | Train Loss: 0.3768 | Train Acc: 0.8636 | Val Loss: 0.3445 | Val Acc: 0.8752 | Patience: 1/5
# Validation loss improved from 0.3452 to 0.3423
# Epoch 52/200 | Train Loss: 0.3752 | Train Acc: 0.8653 | Val Loss: 0.3423 | Val Acc: 0.8746 | Patience: 0/5
# Epoch 53/200 | Train Loss: 0.3717 | Train Acc: 0.8659 | Val Loss: 0.3421 | Val Acc: 0.8759 | Patience: 1/5
# Validation loss improved from 0.3423 to 0.3403
# Epoch 54/200 | Train Loss: 0.3720 | Train Acc: 0.8651 | Val Loss: 0.3403 | Val Acc: 0.8773 | Patience: 0/5
# Epoch 55/200 | Train Loss: 0.3681 | Train Acc: 0.8680 | Val Loss: 0.3420 | Val Acc: 0.8754 | Patience: 1/5
# Validation loss improved from 0.3403 to 0.3380
# Epoch 56/200 | Train Loss: 0.3681 | Train Acc: 0.8690 | Val Loss: 0.3380 | Val Acc: 0.8778 | Patience: 0/5
# Epoch 57/200 | Train Loss: 0.3665 | Train Acc: 0.8671 | Val Loss: 0.3378 | Val Acc: 0.8778 | Patience: 1/5
# Validation loss improved from 0.3380 to 0.3367
# Epoch 58/200 | Train Loss: 0.3631 | Train Acc: 0.8684 | Val Loss: 0.3367 | Val Acc: 0.8769 | Patience: 0/5
# Epoch 59/200 | Train Loss: 0.3622 | Train Acc: 0.8695 | Val Loss: 0.3360 | Val Acc: 0.8787 | Patience: 1/5
# Validation loss improved from 0.3367 to 0.3355
# Epoch 60/200 | Train Loss: 0.3613 | Train Acc: 0.8701 | Val Loss: 0.3355 | Val Acc: 0.8794 | Patience: 0/5
# Validation loss improved from 0.3355 to 0.3343
# Epoch 61/200 | Train Loss: 0.3572 | Train Acc: 0.8709 | Val Loss: 0.3343 | Val Acc: 0.8801 | Patience: 0/5
# Epoch 62/200 | Train Loss: 0.3615 | Train Acc: 0.8692 | Val Loss: 0.3334 | Val Acc: 0.8778 | Patience: 1/5
# Epoch 63/200 | Train Loss: 0.3559 | Train Acc: 0.8716 | Val Loss: 0.3336 | Val Acc: 0.8802 | Patience: 2/5
# Validation loss improved from 0.3343 to 0.3314
# Epoch 64/200 | Train Loss: 0.3544 | Train Acc: 0.8721 | Val Loss: 0.3314 | Val Acc: 0.8798 | Patience: 0/5
# Epoch 65/200 | Train Loss: 0.3549 | Train Acc: 0.8713 | Val Loss: 0.3325 | Val Acc: 0.8802 | Patience: 1/5
# Epoch 66/200 | Train Loss: 0.3530 | Train Acc: 0.8717 | Val Loss: 0.3315 | Val Acc: 0.8804 | Patience: 2/5
# Validation loss improved from 0.3314 to 0.3303
# Epoch 67/200 | Train Loss: 0.3502 | Train Acc: 0.8734 | Val Loss: 0.3303 | Val Acc: 0.8807 | Patience: 0/5
# Epoch 68/200 | Train Loss: 0.3484 | Train Acc: 0.8725 | Val Loss: 0.3294 | Val Acc: 0.8802 | Patience: 1/5
# Validation loss improved from 0.3303 to 0.3288
# Epoch 69/200 | Train Loss: 0.3500 | Train Acc: 0.8741 | Val Loss: 0.3288 | Val Acc: 0.8808 | Patience: 0/5
# Validation loss improved from 0.3288 to 0.3273
# Epoch 70/200 | Train Loss: 0.3479 | Train Acc: 0.8732 | Val Loss: 0.3273 | Val Acc: 0.8815 | Patience: 0/5
# Epoch 71/200 | Train Loss: 0.3463 | Train Acc: 0.8746 | Val Loss: 0.3284 | Val Acc: 0.8821 | Patience: 1/5
# Validation loss improved from 0.3273 to 0.3261
# Epoch 72/200 | Train Loss: 0.3422 | Train Acc: 0.8770 | Val Loss: 0.3261 | Val Acc: 0.8826 | Patience: 0/5
# Epoch 73/200 | Train Loss: 0.3418 | Train Acc: 0.8758 | Val Loss: 0.3259 | Val Acc: 0.8815 | Patience: 1/5
# Validation loss improved from 0.3261 to 0.3248
# Epoch 74/200 | Train Loss: 0.3430 | Train Acc: 0.8757 | Val Loss: 0.3248 | Val Acc: 0.8820 | Patience: 0/5
# Epoch 75/200 | Train Loss: 0.3395 | Train Acc: 0.8779 | Val Loss: 0.3267 | Val Acc: 0.8814 | Patience: 1/5
# Epoch 76/200 | Train Loss: 0.3394 | Train Acc: 0.8766 | Val Loss: 0.3244 | Val Acc: 0.8823 | Patience: 2/5
# Epoch 77/200 | Train Loss: 0.3372 | Train Acc: 0.8778 | Val Loss: 0.3247 | Val Acc: 0.8825 | Patience: 3/5
# Validation loss improved from 0.3248 to 0.3233
# Epoch 78/200 | Train Loss: 0.3350 | Train Acc: 0.8789 | Val Loss: 0.3233 | Val Acc: 0.8828 | Patience: 0/5
# Validation loss improved from 0.3233 to 0.3220
# Epoch 79/200 | Train Loss: 0.3396 | Train Acc: 0.8773 | Val Loss: 0.3220 | Val Acc: 0.8833 | Patience: 0/5
# Validation loss improved from 0.3220 to 0.3210
# Epoch 80/200 | Train Loss: 0.3363 | Train Acc: 0.8781 | Val Loss: 0.3210 | Val Acc: 0.8835 | Patience: 0/5
# Epoch 81/200 | Train Loss: 0.3347 | Train Acc: 0.8779 | Val Loss: 0.3214 | Val Acc: 0.8827 | Patience: 1/5
# Validation loss improved from 0.3210 to 0.3199
# Epoch 82/200 | Train Loss: 0.3316 | Train Acc: 0.8790 | Val Loss: 0.3199 | Val Acc: 0.8832 | Patience: 0/5
# Epoch 83/200 | Train Loss: 0.3327 | Train Acc: 0.8791 | Val Loss: 0.3200 | Val Acc: 0.8834 | Patience: 1/5
# Epoch 84/200 | Train Loss: 0.3309 | Train Acc: 0.8800 | Val Loss: 0.3202 | Val Acc: 0.8840 | Patience: 2/5
# Epoch 85/200 | Train Loss: 0.3306 | Train Acc: 0.8791 | Val Loss: 0.3196 | Val Acc: 0.8830 | Patience: 3/5
# Validation loss improved from 0.3199 to 0.3186
# Epoch 86/200 | Train Loss: 0.3276 | Train Acc: 0.8809 | Val Loss: 0.3186 | Val Acc: 0.8832 | Patience: 0/5
# Epoch 87/200 | Train Loss: 0.3250 | Train Acc: 0.8811 | Val Loss: 0.3181 | Val Acc: 0.8847 | Patience: 1/5
# Epoch 88/200 | Train Loss: 0.3249 | Train Acc: 0.8820 | Val Loss: 0.3192 | Val Acc: 0.8848 | Patience: 2/5
# Epoch 89/200 | Train Loss: 0.3252 | Train Acc: 0.8821 | Val Loss: 0.3179 | Val Acc: 0.8840 | Patience: 3/5
# Validation loss improved from 0.3186 to 0.3164
# Epoch 90/200 | Train Loss: 0.3230 | Train Acc: 0.8826 | Val Loss: 0.3164 | Val Acc: 0.8858 | Patience: 0/5
# Epoch 91/200 | Train Loss: 0.3243 | Train Acc: 0.8818 | Val Loss: 0.3162 | Val Acc: 0.8853 | Patience: 1/5
# Validation loss improved from 0.3164 to 0.3152
# Epoch 92/200 | Train Loss: 0.3216 | Train Acc: 0.8836 | Val Loss: 0.3152 | Val Acc: 0.8873 | Patience: 0/5
# Epoch 93/200 | Train Loss: 0.3195 | Train Acc: 0.8841 | Val Loss: 0.3143 | Val Acc: 0.8866 | Patience: 1/5
# Epoch 94/200 | Train Loss: 0.3203 | Train Acc: 0.8842 | Val Loss: 0.3157 | Val Acc: 0.8868 | Patience: 2/5
# Epoch 95/200 | Train Loss: 0.3179 | Train Acc: 0.8847 | Val Loss: 0.3143 | Val Acc: 0.8865 | Patience: 3/5
# Epoch 96/200 | Train Loss: 0.3181 | Train Acc: 0.8832 | Val Loss: 0.3153 | Val Acc: 0.8854 | Patience: 4/5
# Validation loss improved from 0.3152 to 0.3129
# Epoch 97/200 | Train Loss: 0.3142 | Train Acc: 0.8859 | Val Loss: 0.3129 | Val Acc: 0.8866 | Patience: 0/5
# Epoch 98/200 | Train Loss: 0.3150 | Train Acc: 0.8871 | Val Loss: 0.3141 | Val Acc: 0.8862 | Patience: 1/5
# Epoch 99/200 | Train Loss: 0.3145 | Train Acc: 0.8846 | Val Loss: 0.3133 | Val Acc: 0.8877 | Patience: 2/5
# Epoch 100/200 | Train Loss: 0.3126 | Train Acc: 0.8871 | Val Loss: 0.3130 | Val Acc: 0.8876 | Patience: 3/5
# Epoch 101/200 | Train Loss: 0.3135 | Train Acc: 0.8858 | Val Loss: 0.3127 | Val Acc: 0.8863 | Patience: 4/5
# Validation loss improved from 0.3129 to 0.3117
# Epoch 102/200 | Train Loss: 0.3098 | Train Acc: 0.8876 | Val Loss: 0.3117 | Val Acc: 0.8876 | Patience: 0/5
# Epoch 103/200 | Train Loss: 0.3075 | Train Acc: 0.8880 | Val Loss: 0.3110 | Val Acc: 0.8872 | Patience: 1/5
# Epoch 104/200 | Train Loss: 0.3095 | Train Acc: 0.8881 | Val Loss: 0.3118 | Val Acc: 0.8871 | Patience: 2/5
# Epoch 105/200 | Train Loss: 0.3090 | Train Acc: 0.8878 | Val Loss: 0.3112 | Val Acc: 0.8888 | Patience: 3/5
# Epoch 106/200 | Train Loss: 0.3091 | Train Acc: 0.8888 | Val Loss: 0.3109 | Val Acc: 0.8888 | Patience: 4/5
# Validation loss improved from 0.3117 to 0.3095
# Epoch 107/200 | Train Loss: 0.3058 | Train Acc: 0.8891 | Val Loss: 0.3095 | Val Acc: 0.8881 | Patience: 0/5
# Epoch 108/200 | Train Loss: 0.3053 | Train Acc: 0.8895 | Val Loss: 0.3100 | Val Acc: 0.8890 | Patience: 1/5
# Epoch 109/200 | Train Loss: 0.3030 | Train Acc: 0.8886 | Val Loss: 0.3093 | Val Acc: 0.8865 | Patience: 2/5
# Epoch 110/200 | Train Loss: 0.3026 | Train Acc: 0.8903 | Val Loss: 0.3098 | Val Acc: 0.8882 | Patience: 3/5
# Epoch 111/200 | Train Loss: 0.3040 | Train Acc: 0.8896 | Val Loss: 0.3095 | Val Acc: 0.8872 | Patience: 4/5
#
# Early stopping at epoch 112 (best epoch: 107)
# Test Accuracy: 0.8846

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
architectures = [
    "784, 128, 10 (ReLU, 0.2)",
    "784, 128, 10 (ReLU, 0)",
    "784, 128, 10 (GELU, 0.2)",
    "784, 128, 10 (GELU, 0)",
    "784, 128, 10 (Leaky-GELU, 0.2)",
    "784, 400, 250, 100, 10 (ReLU, 0.2)",
    "784, 400, 250, 100, 10 (Leaky-ReLU, 0.2)",
    "784, 256, 128, 10 (GELU, 0.2)"
]

accuracy = [88.25, 88.15, 88.35, 87.87, 87.96, 88.55, 88.34, 88.46]

# Sort data based on accuracy
sorted_indices = np.argsort(accuracy)
architectures = [architectures[i] for i in sorted_indices]
accuracy = [accuracy[i] for i in sorted_indices]

# Plot settings
plt.figure(figsize=(12, 6))
y_pos = np.arange(len(architectures))
plt.barh(y_pos, accuracy, color='skyblue', edgecolor='black')
plt.yticks(y_pos, architectures)
plt.xlabel('Accuracy (%)')
plt.xlim(min(accuracy) - 0.2, max(accuracy) + 0.2)  # Zoom in on the accuracy range
plt.ylabel('MLP Architecture (Activation, Dropout)')
plt.title('MLP Classification Accuracy for Different Architectures')
plt.gca().invert_yaxis()  # Highest accuracy on top

# Display values on bars
for index, value in enumerate(accuracy):
    plt.text(value - 0.1, index, f"{value:.2f}%", va='center', fontsize=10)

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
